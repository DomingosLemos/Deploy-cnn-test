# %% [markdown]
# <a href="https://colab.research.google.com/github/DomingosLemos/Deploy-cnn-test/blob/main/Inception.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Inception

# %% [markdown]
# # Import the necessary libraries

# %%
# !pip install split-folders
import splitfolders
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import load_model
import tensorflow as tf
from tensorflow.keras import regularizers
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Convolution2D, MaxPooling2D, ZeroPadding2D, GlobalAveragePooling2D, AveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import SGD
from tensorflow import keras
from tensorflow.keras import models
import cv2
from sklearn.metrics import confusion_matrix,classification_report

#models
from keras.applications.inception_v3 import InceptionV3
# Out:
# Collecting split-folders
#   Downloading https://files.pythonhosted.org/packages/b8/5f/3c2b2f7ea5e047c8cdc3bb00ae582c5438fcdbbedcc23b3cc1c2c7aae642/split_folders-0.4.3-py3-none-any.whl
# Installing collected packages: split-folders
# Successfully installed split-folders-0.4.3

# %% [markdown]
# ### Mount the google drive where we have a zip with all the images

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Unzip images to folders

# %%
!7z x /content/drive/MyDrive/EDSA/images.zip -o/content/images
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 5132666035 bytes (4895 MiB)
#
# Extracting archive: /content/drive/MyDrive/EDSA/images.zip
# --
# Path = /content/drive/MyDrive/EDSA/images.zip
# Type = zip
# Physical Size = 5132666035
# 64-bit = +
#
# Everything is Ok
#
# Folders: 101
# Files: 101000
# Size:       5116621947
# Compressed: 5132666035

# %% [markdown]
# ### Split images with splitfolder
# Put on:
# * content/output/train with 70% (700 images for each folder)
# * content/output/val with 20% (200 images for each folder)
# * content/output/test with 10% (100 images for each folder)

# %%
splitfolders.ratio('/content/images', output="output", seed=1337, ratio=(.7, .2, .1))
# Out:
# Copying files: 101000 files [02:17, 735.39 files/s]

# %% [markdown]
# ## Inception model
#
# As we have a small dataset for each category (700 images) we will use "Image Augmentation" to increase the size of our dataset a little

# %%
#Add our data-augmentation parameters to ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1. / 255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1. / 255)

# %% [markdown]
# ### Get the data

# %%
#n_classes = 101
img_width, img_height = 299, 299 # Standard shape for pre-trained model
train_data_dir = '/content/output/train'
validation_data_dir = '/content/output/val'
nb_train_samples = 70700
nb_validation_samples = 20200
batch_size = 16

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical')
# Out:
# Found 70700 images belonging to 101 classes.
# Found 20200 images belonging to 101 classes.

# %%
#Build the model
inception = InceptionV3(weights='imagenet', include_top=False)
x = inception.output
x = GlobalAveragePooling2D()(x)
x = Dense(128,activation='relu')(x)
x = Dropout(0.2)(x)

predictions = Dense(101,kernel_regularizer=regularizers.l2(0.005), activation='softmax')(x)

model = Model(inputs=inception.input, outputs=predictions)

# Compile model
model.compile(optimizer=SGD(lr=0.0001, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])
checkpointer = ModelCheckpoint(filepath='best_model_3class.hdf5', verbose=1, save_best_only=True)

# Fit model
history = model.fit_generator(train_generator,
                    steps_per_epoch = nb_train_samples // batch_size,
                    validation_data=validation_generator,
                    validation_steps=nb_validation_samples // batch_size,
                    epochs=30,
                    verbose=1,
                    callbacks=[checkpointer])

model.save('model_trained_3class.hdf5')
# Out:
# Found 70700 images belonging to 101 classes.
# Found 20200 images belonging to 101 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/30
# 4418/4418 [==============================] - 1875s 422ms/step - loss: 5.0553 - accuracy: 0.0407 - val_loss: 3.9280 - val_accuracy: 0.2904
#
# Epoch 00001: val_loss improved from inf to 3.92801, saving model to best_model_3class.hdf5
# Epoch 2/30
# 4418/4418 [==============================] - 1831s 415ms/step - loss: 3.8302 - accuracy: 0.2761 - val_loss: 2.6612 - val_accuracy: 0.5042
#
# Epoch 00002: val_loss improved from 3.92801 to 2.66116, saving model to best_model_3class.hdf5
# Epoch 3/30
# 4418/4418 [==============================] - 1783s 403ms/step - loss: 2.9322 - accuracy: 0.4278 - val_loss: 2.1312 - val_accuracy: 0.6059
#
# Epoch 00003: val_loss improved from 2.66116 to 2.13121, saving model to best_model_3class.hdf5
# Epoch 4/30
# 4418/4418 [==============================] - 1758s 398ms/step - loss: 2.4642 - accuracy: 0.5217 - val_loss: 1.8449 - val_accuracy: 0.6603
#
# Epoch 00004: val_loss improved from 2.13121 to 1.84488, saving model to best_model_3class.hdf5
# Epoch 5/30
# 4418/4418 [==============================] - 1774s 401ms/step - loss: 2.1663 - accuracy: 0.5820 - val_loss: 1.6988 - val_accuracy: 0.6814
#
# Epoch 00005: val_loss improved from 1.84488 to 1.69877, saving model to best_model_3class.hdf5
# Epoch 6/30
# 4418/4418 [==============================] - 1721s 389ms/step - loss: 1.9550 - accuracy: 0.6245 - val_loss: 1.5618 - val_accuracy: 0.7082
#
# Epoch 00006: val_loss improved from 1.69877 to 1.56178, saving model to best_model_3class.hdf5
# Epoch 7/30
# 4418/4418 [==============================] - 1698s 384ms/step - loss: 1.7953 - accuracy: 0.6565 - val_loss: 1.4820 - val_accuracy: 0.7203
#
# Epoch 00007: val_loss improved from 1.56178 to 1.48197, saving model to best_model_3class.hdf5
# Epoch 8/30
# 4418/4418 [==============================] - 1838s 416ms/step - loss: 1.6735 - accuracy: 0.6790 - val_loss: 1.4187 - val_accuracy: 0.7303
#
# Epoch 00008: val_loss improved from 1.48197 to 1.41871, saving model to best_model_3class.hdf5
# Epoch 9/30
# 4418/4418 [==============================] - 1706s 386ms/step - loss: 1.5611 - accuracy: 0.7028 - val_loss: 1.3568 - val_accuracy: 0.7426
#
# Epoch 00009: val_loss improved from 1.41871 to 1.35685, saving model to best_model_3class.hdf5
# Epoch 10/30
# 4418/4418 [==============================] - 1665s 377ms/step - loss: 1.4572 - accuracy: 0.7257 - val_loss: 1.3239 - val_accuracy: 0.7471
#
# Epoch 00010: val_loss improved from 1.35685 to 1.32389, saving model to best_model_3class.hdf5
# Epoch 11/30
# 4418/4418 [==============================] - 1687s 382ms/step - loss: 1.3765 - accuracy: 0.7401 - val_loss: 1.2689 - val_accuracy: 0.7569
#
# Epoch 00011: val_loss improved from 1.32389 to 1.26888, saving model to best_model_3class.hdf5
# Epoch 12/30
# 4418/4418 [==============================] - 1717s 389ms/step - loss: 1.3092 - accuracy: 0.7529 - val_loss: 1.2424 - val_accuracy: 0.7599
#
# Epoch 00012: val_loss improved from 1.26888 to 1.24241, saving model to best_model_3class.hdf5
# Epoch 13/30
# 4418/4418 [==============================] - 1876s 425ms/step - loss: 1.2368 - accuracy: 0.7698 - val_loss: 1.2040 - val_accuracy: 0.7664
#
# Epoch 00013: val_loss improved from 1.24241 to 1.20398, saving model to best_model_3class.hdf5
# Epoch 14/30
# 4418/4418 [==============================] - 1678s 380ms/step - loss: 1.1841 - accuracy: 0.7759 - val_loss: 1.1704 - val_accuracy: 0.7735
#
# Epoch 00014: val_loss improved from 1.20398 to 1.17044, saving model to best_model_3class.hdf5
# Epoch 15/30
# 4418/4418 [==============================] - 1654s 374ms/step - loss: 1.1202 - accuracy: 0.7918 - val_loss: 1.1505 - val_accuracy: 0.7770
#
# Epoch 00015: val_loss improved from 1.17044 to 1.15055, saving model to best_model_3class.hdf5
# Epoch 16/30
# 4418/4418 [==============================] - 1755s 397ms/step - loss: 1.0701 - accuracy: 0.8015 - val_loss: 1.1433 - val_accuracy: 0.7749
#
# Epoch 00016: val_loss improved from 1.15055 to 1.14334, saving model to best_model_3class.hdf5
# Epoch 17/30
# 4418/4418 [==============================] - 1869s 423ms/step - loss: 1.0191 - accuracy: 0.8092 - val_loss: 1.1220 - val_accuracy: 0.7791
#
# Epoch 00017: val_loss improved from 1.14334 to 1.12202, saving model to best_model_3class.hdf5
# Epoch 18/30
# 4418/4418 [==============================] - 1873s 424ms/step - loss: 0.9766 - accuracy: 0.8204 - val_loss: 1.1031 - val_accuracy: 0.7813
#
# Epoch 00018: val_loss improved from 1.12202 to 1.10312, saving model to best_model_3class.hdf5
# Epoch 19/30
# 4418/4418 [==============================] - 1898s 430ms/step - loss: 0.9307 - accuracy: 0.8300 - val_loss: 1.1053 - val_accuracy: 0.7802
#
# Epoch 00019: val_loss did not improve from 1.10312
# Epoch 20/30
# 4418/4418 [==============================] - 1876s 425ms/step - loss: 0.8845 - accuracy: 0.8378 - val_loss: 1.0805 - val_accuracy: 0.7845
#
# Epoch 00020: val_loss improved from 1.10312 to 1.08047, saving model to best_model_3class.hdf5
# Epoch 21/30
# 4418/4418 [==============================] - 1740s 394ms/step - loss: 0.8698 - accuracy: 0.8381 - val_loss: 1.0671 - val_accuracy: 0.7865
#
# Epoch 00021: val_loss improved from 1.08047 to 1.06710, saving model to best_model_3class.hdf5
# Epoch 22/30
# 4418/4418 [==============================] - 1665s 377ms/step - loss: 0.8275 - accuracy: 0.8483 - val_loss: 1.0635 - val_accuracy: 0.7883
#
# Epoch 00022: val_loss improved from 1.06710 to 1.06353, saving model to best_model_3class.hdf5
# Epoch 23/30
# 4418/4418 [==============================] - 1737s 393ms/step - loss: 0.7960 - accuracy: 0.8573 - val_loss: 1.0602 - val_accuracy: 0.7882
#
# Epoch 00023: val_loss improved from 1.06353 to 1.06024, saving model to best_model_3class.hdf5
# Epoch 24/30
# 4418/4418 [==============================] - 1917s 434ms/step - loss: 0.7588 - accuracy: 0.8642 - val_loss: 1.0471 - val_accuracy: 0.7895
#
# Epoch 00024: val_loss improved from 1.06024 to 1.04706, saving model to best_model_3class.hdf5
# Epoch 25/30
# 4418/4418 [==============================] - 1909s 432ms/step - loss: 0.7333 - accuracy: 0.8695 - val_loss: 1.0498 - val_accuracy: 0.7903
#
# Epoch 00025: val_loss did not improve from 1.04706
# Epoch 26/30
# 4418/4418 [==============================] - 1754s 397ms/step - loss: 0.7044 - accuracy: 0.8750 - val_loss: 1.0437 - val_accuracy: 0.7886
#
# Epoch 00026: val_loss improved from 1.04706 to 1.04367, saving model to best_model_3class.hdf5
# Epoch 27/30
# 4418/4418 [==============================] - 1635s 370ms/step - loss: 0.6839 - accuracy: 0.8795 - val_loss: 1.0344 - val_accuracy: 0.7898
#
# Epoch 00027: val_loss improved from 1.04367 to 1.03439, saving model to best_model_3class.hdf5
# Epoch 28/30
# 4418/4418 [==============================] - 1631s 369ms/step - loss: 0.6465 - accuracy: 0.8893 - val_loss: 1.0421 - val_accuracy: 0.7893
#
# Epoch 00028: val_loss did not improve from 1.03439
# Epoch 29/30
# 4418/4418 [==============================] - 1632s 369ms/step - loss: 0.6251 - accuracy: 0.8925 - val_loss: 1.0389 - val_accuracy: 0.7893
#
# Epoch 00029: val_loss did not improve from 1.03439
# Epoch 30/30
# 4418/4418 [==============================] - 1685s 381ms/step - loss: 0.6097 - accuracy: 0.8962 - val_loss: 1.0277 - val_accuracy: 0.7933
#
# Epoch 00030: val_loss improved from 1.03439 to 1.02769, saving model to best_model_3class.hdf5

# %% [markdown]
# ## Evaluating the Inception Model

# %%
test_datagen = ImageDataGenerator(rescale=1. / 255)

batch_size = 16
img_width, img_height = 299, 299

test_generator=test_datagen.flow_from_directory(directory="/content/output/test/", 
                                                  batch_size=batch_size,
                                                  shuffle=False, #Shuffle was changed to false in order to ensure that the images were predicted in the correct order
                                                  class_mode="categorical",
                                                  target_size=(img_width, img_height),
                                                  seed=42)
# Out:
# Found 10100 images belonging to 101 classes.

# %%
#rename file 
# !cp /content/drive/MyDrive/EDSA/model_trained_3class.hdf5 /content/drive/MyDrive/EDSA/best_model.h5

# %%
#Load model saved
 
Best_Model = load_model('/content/drive/MyDrive/EDSA/best_model.h5')

# %%
#https://stackoverflow.com/questions/53929819/generating-confusion-matrix-in-keras-for-multiclass-classification


predictions = Best_Model.predict_generator(test_generator)

y_pred = np.argmax(predictions, axis=1)

true_classes = test_generator.classes

class_labels = list(test_generator.class_indices.keys())   

print(class_labels)

print(confusion_matrix(test_generator.classes, y_pred))

report = classification_report(true_classes, y_pred, target_names=class_labels)
print(report)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1905: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# ['apple_pie', 'baby_back_ribs', 'baklava', 'beef_carpaccio', 'beef_tartare', 'beet_salad', 'beignets', 'bibimbap', 'bread_pudding', 'breakfast_burrito', 'bruschetta', 'caesar_salad', 'cannoli', 'caprese_salad', 'carrot_cake', 'ceviche', 'cheese_plate', 'cheesecake', 'chicken_curry', 'chicken_quesadilla', 'chicken_wings', 'chocolate_cake', 'chocolate_mousse', 'churros', 'clam_chowder', 'club_sandwich', 'crab_cakes', 'creme_brulee', 'croque_madame', 'cup_cakes', 'deviled_eggs', 'donuts', 'dumplings', 'edamame', 'eggs_benedict', 'escargots', 'falafel', 'filet_mignon', 'fish_and_chips', 'foie_gras', 'french_fries', 'french_onion_soup', 'french_toast', 'fried_calamari', 'fried_rice', 'frozen_yogurt', 'garlic_bread', 'gnocchi', 'greek_salad', 'grilled_cheese_sandwich', 'grilled_salmon', 'guacamole', 'gyoza', 'hamburger', 'hot_and_sour_soup', 'hot_dog', 'huevos_rancheros', 'hummus', 'ice_cream', 'lasagna', 'lobster_bisque', 'lobster_roll_sandwich', 'macaroni_and_cheese', 'macarons', 'miso_soup', 'mussels', 'nachos', 'omelette', 'onion_rings', 'oysters', 'pad_thai', 'paella', 'pancakes', 'panna_cotta', 'peking_duck', 'pho', 'pizza', 'pork_chop', 'poutine', 'prime_rib', 'pulled_pork_sandwich', 'ramen', 'ravioli', 'red_velvet_cake', 'risotto', 'samosa', 'sashimi', 'scallops', 'seaweed_salad', 'shrimp_and_grits', 'spaghetti_bolognese', 'spaghetti_carbonara', 'spring_rolls', 'steak', 'strawberry_shortcake', 'sushi', 'tacos', 'takoyaki', 'tiramisu', 'tuna_tartare', 'waffles']
# [[60  1  4 ...  0  0  0]
#  [ 0 77  1 ...  0  1  0]
#  [ 2  0 79 ...  0  1  0]
#  ...
#  [ 0  0  0 ... 79  0  0]
#  [ 0  0  0 ...  0 71  0]
#  [ 2  0  0 ...  0  0 81]]
#                          precision    recall  f1-score   support
#
#               apple_pie       0.62      0.60      0.61       100
#          baby_back_ribs       0.83      0.77      0.80       100
#                 baklava       0.83      0.79      0.81       100
#          beef_carpaccio       0.80      0.84      0.82       100
#            beef_tartare       0.75      0.74      0.74       100
#              beet_salad       0.62      0.60      0.61       100
#                beignets       0.87      0.86      0.86       100
#                bibimbap       0.89      0.85      0.87       100
#           bread_pudding       0.57      0.58      0.57       100
#       breakfast_burrito       0.74      0.74      0.74       100
#              bruschetta       0.71      0.75      0.73       100
#            caesar_salad       0.84      0.84      0.84       100
#                 cannoli       0.92      0.89      0.90       100
#           caprese_salad       0.72      0.86      0.78       100
#             carrot_cake       0.79      0.71      0.75       100
#                 ceviche       0.73      0.64      0.68       100
#            cheese_plate       0.76      0.84      0.80       100
#              cheesecake       0.77      0.77      0.77       100
#           chicken_curry       0.75      0.70      0.73       100
#      chicken_quesadilla       0.79      0.80      0.80       100
#           chicken_wings       0.88      0.84      0.86       100
#          chocolate_cake       0.78      0.65      0.71       100
#        chocolate_mousse       0.59      0.72      0.65       100
#                 churros       0.88      0.87      0.87       100
#            clam_chowder       0.83      0.86      0.84       100
#           club_sandwich       0.81      0.85      0.83       100
#              crab_cakes       0.77      0.78      0.78       100
#            creme_brulee       0.90      0.87      0.88       100
#           croque_madame       0.87      0.79      0.83       100
#               cup_cakes       0.80      0.92      0.86       100
#            deviled_eggs       0.88      0.92      0.90       100
#                  donuts       0.81      0.81      0.81       100
#               dumplings       0.87      0.85      0.86       100
#                 edamame       0.99      0.95      0.97       100
#           eggs_benedict       0.81      0.91      0.86       100
#               escargots       0.74      0.87      0.80       100
#                 falafel       0.83      0.68      0.75       100
#            filet_mignon       0.70      0.57      0.63       100
#          fish_and_chips       0.83      0.85      0.84       100
#               foie_gras       0.60      0.68      0.64       100
#            french_fries       0.88      0.92      0.90       100
#       french_onion_soup       0.86      0.85      0.85       100
#            french_toast       0.74      0.81      0.78       100
#          fried_calamari       0.85      0.83      0.84       100
#              fried_rice       0.85      0.85      0.85       100
#           frozen_yogurt       0.79      0.92      0.85       100
#            garlic_bread       0.86      0.74      0.80       100
#                 gnocchi       0.69      0.72      0.70       100
#             greek_salad       0.78      0.77      0.77       100
# grilled_cheese_sandwich       0.72      0.65      0.68       100
#          grilled_salmon       0.67      0.73      0.70       100
#               guacamole       0.84      0.88      0.86       100
#                   gyoza       0.88      0.83      0.86       100
#               hamburger       0.74      0.86      0.80       100
#       hot_and_sour_soup       0.94      0.91      0.92       100
#                 hot_dog       0.81      0.82      0.82       100
#        huevos_rancheros       0.76      0.69      0.72       100
#                  hummus       0.73      0.64      0.68       100
#               ice_cream       0.74      0.73      0.74       100
#                 lasagna       0.76      0.72      0.74       100
#          lobster_bisque       0.86      0.87      0.87       100
#   lobster_roll_sandwich       0.91      0.87      0.89       100
#     macaroni_and_cheese       0.77      0.82      0.79       100
#                macarons       0.96      0.92      0.94       100
#               miso_soup       0.92      0.92      0.92       100
#                 mussels       0.90      0.90      0.90       100
#                  nachos       0.92      0.66      0.77       100
#                omelette       0.79      0.70      0.74       100
#             onion_rings       0.88      0.88      0.88       100
#                 oysters       0.90      0.87      0.88       100
#                pad_thai       0.87      0.88      0.88       100
#                  paella       0.80      0.80      0.80       100
#                pancakes       0.87      0.76      0.81       100
#             panna_cotta       0.72      0.63      0.67       100
#             peking_duck       0.73      0.83      0.78       100
#                     pho       0.84      0.91      0.87       100
#                   pizza       0.85      0.87      0.86       100
#               pork_chop       0.58      0.59      0.59       100
#                 poutine       0.87      0.87      0.87       100
#               prime_rib       0.77      0.82      0.80       100
#    pulled_pork_sandwich       0.83      0.83      0.83       100
#                   ramen       0.75      0.88      0.81       100
#                 ravioli       0.70      0.62      0.66       100
#         red_velvet_cake       0.91      0.84      0.87       100
#                 risotto       0.70      0.79      0.74       100
#                  samosa       0.85      0.86      0.86       100
#                 sashimi       0.89      0.93      0.91       100
#                scallops       0.66      0.62      0.64       100
#           seaweed_salad       0.88      0.93      0.90       100
#        shrimp_and_grits       0.70      0.69      0.69       100
#     spaghetti_bolognese       0.92      0.92      0.92       100
#     spaghetti_carbonara       0.92      0.90      0.91       100
#            spring_rolls       0.86      0.83      0.84       100
#                   steak       0.55      0.60      0.57       100
#    strawberry_shortcake       0.75      0.82      0.78       100
#                   sushi       0.78      0.76      0.77       100
#                   tacos       0.78      0.68      0.73       100
#                takoyaki       0.90      0.88      0.89       100
#                tiramisu       0.83      0.79      0.81       100
#            tuna_tartare       0.55      0.71      0.62       100
#                 waffles       0.91      0.81      0.86       100
#
#                accuracy                           0.80     10100
#               macro avg       0.80      0.80      0.80     10100
#            weighted avg       0.80      0.80      0.80     10100
